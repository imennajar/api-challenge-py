# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
from scipy.stats import linregress
import scipy

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list

# %%
# Set the API base URL

api_key = weather_api_key

url  =f'http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units=metric&q='

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url+city

   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date

        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind =city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date =city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | sampacho
# Processing Record 3 of Set 1 | salekhard
# Processing Record 4 of Set 1 | peace river
# Processing Record 5 of Set 1 | meadow lakes
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | afaahiti
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | nova sintra
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | talara
# Processing Record 13 of Set 1 | papao
# Processing Record 14 of Set 1 | kingston
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | madang
# Processing Record 17 of Set 1 | fale old settlement
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | ouellah
# City not found. Skipping...
# Processing Record 20 of Set 1 | ust-nera
# Processing Record 21 of Set 1 | hozat
# Processing Record 22 of Set 1 | lata
# Processing Record 23 of Set 1 | praia da vitoria
# Processing Record 24 of Set 1 | grytviken
# Processing Record 25 of Set 1 | madalena
# Processing Record 26 of Set 1 | palu
# Processing Record 27 of Set 1 | alupka
# Processing Record 28 of Set 1 | vernon
# Processing Record 29 of Set 1 | aasiaat
# Processing Record 30 of Set 1 | nishinoomote
# Processing Record 31 of Set 1 | atafu village
# Processing Record 32 of Set 1 | bilibino
# Processing Record 33 of Set 1 | san angelo
# Processing Record 34 of Set 1 | blackmans bay
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | san felipe
# Processing Record 37 of Set 1 | dryden
# Processing Record 38 of Set 1 | izki
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | gamba
# Processing Record 41 of Set 1 | papatowai
# Processing Record 42 of Set 1 | labuan
# Processing Record 43 of Set 1 | hawaiian paradise park
# Processing Record 44 of Set 1 | al ghayzah
# Processing Record 45 of Set 1 | turek
# Processing Record 46 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | namibe
# Processing Record 49 of Set 1 | lihue
# Processing Record 50 of Set 1 | port lincoln
# Processing Record 0 of Set 2 | labrador city
# Processing Record 1 of Set 2 | tabou
# Processing Record 2 of Set 2 | revda
# Processing Record 3 of Set 2 | constitucion
# Processing Record 4 of Set 2 | murzuq
# Processing Record 5 of Set 2 | pemangkat
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | susuman
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | puerto natales
# Processing Record 10 of Set 2 | wanning
# Processing Record 11 of Set 2 | thunder bay
# Processing Record 12 of Set 2 | eldorado
# Processing Record 13 of Set 2 | olean
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | jayapura
# Processing Record 16 of Set 2 | eastham
# Processing Record 17 of Set 2 | balykshi
# Processing Record 18 of Set 2 | touros
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | taoudenni
# Processing Record 21 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 22 of Set 2 | burang
# Processing Record 23 of Set 2 | tolanaro
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | edinburgh of the seven seas
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | castuera
# Processing Record 28 of Set 2 | college
# Processing Record 29 of Set 2 | malango
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | puerto deseado
# Processing Record 33 of Set 2 | morki
# Processing Record 34 of Set 2 | adel
# Processing Record 35 of Set 2 | invercargill
# Processing Record 36 of Set 2 | lloydminster
# Processing Record 37 of Set 2 | reggane
# Processing Record 38 of Set 2 | hadibu
# Processing Record 39 of Set 2 | mancio lima
# Processing Record 40 of Set 2 | whitehorse
# Processing Record 41 of Set 2 | aykhal
# Processing Record 42 of Set 2 | katsuren-haebaru
# Processing Record 43 of Set 2 | tazovsky
# Processing Record 44 of Set 2 | nizhnyaya omka
# Processing Record 45 of Set 2 | chonchi
# Processing Record 46 of Set 2 | sao bento
# Processing Record 47 of Set 2 | powell
# Processing Record 48 of Set 2 | troitsko-pechorsk
# Processing Record 49 of Set 2 | zambezi
# Processing Record 0 of Set 3 | riviere-du-loup
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | nguigmi
# Processing Record 4 of Set 3 | harstad
# Processing Record 5 of Set 3 | jalai nur
# Processing Record 6 of Set 3 | saint-pierre
# Processing Record 7 of Set 3 | tanjung pandan
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | am timan
# Processing Record 10 of Set 3 | iskateley
# Processing Record 11 of Set 3 | luganville
# Processing Record 12 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 13 of Set 3 | cafayate
# Processing Record 14 of Set 3 | tamanrasset
# Processing Record 15 of Set 3 | antonio enes
# Processing Record 16 of Set 3 | floro
# Processing Record 17 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 18 of Set 3 | weno
# Processing Record 19 of Set 3 | campo maior
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | trairi
# Processing Record 22 of Set 3 | yanchep
# Processing Record 23 of Set 3 | karratha
# Processing Record 24 of Set 3 | qaqortoq
# Processing Record 25 of Set 3 | governor's harbour
# City not found. Skipping...
# Processing Record 26 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | zhanjiang
# Processing Record 29 of Set 3 | ciudad lazaro cardenas
# Processing Record 30 of Set 3 | jumla
# Processing Record 31 of Set 3 | west island
# Processing Record 32 of Set 3 | uturoa
# Processing Record 33 of Set 3 | reyes
# Processing Record 34 of Set 3 | okhotsk
# Processing Record 35 of Set 3 | wailua homesteads
# Processing Record 36 of Set 3 | kapuskasing
# Processing Record 37 of Set 3 | st. john's
# Processing Record 38 of Set 3 | rikaze
# Processing Record 39 of Set 3 | nogliki
# Processing Record 40 of Set 3 | siwa oasis
# Processing Record 41 of Set 3 | mejit
# Processing Record 42 of Set 3 | berezovo
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | fort bragg
# Processing Record 45 of Set 3 | albany
# Processing Record 46 of Set 3 | strelka
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | bibiani
# Processing Record 49 of Set 3 | rio de janeiro
# Processing Record 0 of Set 4 | sheridan
# Processing Record 1 of Set 4 | at taj
# Processing Record 2 of Set 4 | sinan
# Processing Record 3 of Set 4 | coahuayana de hidalgo
# Processing Record 4 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 4 | chibougamau
# Processing Record 6 of Set 4 | yellowknife
# Processing Record 7 of Set 4 | sharm el-sheikh
# Processing Record 8 of Set 4 | gunjur
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | saipan
# Processing Record 11 of Set 4 | cestos city
# Processing Record 12 of Set 4 | happy valley-goose bay
# Processing Record 13 of Set 4 | stanley
# Processing Record 14 of Set 4 | kailua-kona
# Processing Record 15 of Set 4 | tazacorte
# Processing Record 16 of Set 4 | al kharijah
# Processing Record 17 of Set 4 | polyarnyy
# Processing Record 18 of Set 4 | ormara
# Processing Record 19 of Set 4 | donmatias
# Processing Record 20 of Set 4 | pinotepa nacional
# Processing Record 21 of Set 4 | newman
# Processing Record 22 of Set 4 | portland
# Processing Record 23 of Set 4 | grande prairie
# Processing Record 24 of Set 4 | fonte boa
# Processing Record 25 of Set 4 | hermanus
# Processing Record 26 of Set 4 | port augusta
# Processing Record 27 of Set 4 | wamba
# Processing Record 28 of Set 4 | irymple
# Processing Record 29 of Set 4 | saurimo
# Processing Record 30 of Set 4 | waingapu
# Processing Record 31 of Set 4 | ancud
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | little cayman
# City not found. Skipping...
# Processing Record 34 of Set 4 | dudinka
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | margaret river
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | aripuana
# Processing Record 40 of Set 4 | yigo village
# Processing Record 41 of Set 4 | san juan de miraflores
# Processing Record 42 of Set 4 | governador valadares
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | laojunmiao
# Processing Record 45 of Set 4 | sortavala
# Processing Record 46 of Set 4 | klyuchi
# Processing Record 47 of Set 4 | konarka
# Processing Record 48 of Set 4 | ishigaki
# Processing Record 49 of Set 4 | sarapul
# Processing Record 0 of Set 5 | horta
# Processing Record 1 of Set 5 | puerto ayora
# Processing Record 2 of Set 5 | utrik
# Processing Record 3 of Set 5 | manokwari
# Processing Record 4 of Set 5 | suzhou
# Processing Record 5 of Set 5 | al hufuf
# Processing Record 6 of Set 5 | bonnyville
# Processing Record 7 of Set 5 | kone
# Processing Record 8 of Set 5 | isafjordur
# Processing Record 9 of Set 5 | bonthe
# Processing Record 10 of Set 5 | gyumri
# Processing Record 11 of Set 5 | khorugh
# Processing Record 12 of Set 5 | khartoum
# Processing Record 13 of Set 5 | timimoun
# Processing Record 14 of Set 5 | wobulenzi
# Processing Record 15 of Set 5 | champerico
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | jales
# Processing Record 18 of Set 5 | jilib
# Processing Record 19 of Set 5 | mtsensk
# Processing Record 20 of Set 5 | silistra
# Processing Record 21 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 5 | hanceville
# Processing Record 23 of Set 5 | itoman
# Processing Record 24 of Set 5 | karakol
# Processing Record 25 of Set 5 | ust'-ilimsk
# Processing Record 26 of Set 5 | balcesti
# Processing Record 27 of Set 5 | san clemente del tuyu
# Processing Record 28 of Set 5 | chapeco
# Processing Record 29 of Set 5 | shahrud
# Processing Record 30 of Set 5 | garissa
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | oum hadjer
# Processing Record 33 of Set 5 | kurchatov
# Processing Record 34 of Set 5 | serdar
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | prachin buri
# Processing Record 37 of Set 5 | egilsstadir
# Processing Record 38 of Set 5 | vila franca do campo
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | new norfolk
# Processing Record 41 of Set 5 | walvis bay
# Processing Record 42 of Set 5 | guaraniacu
# Processing Record 43 of Set 5 | tralee
# Processing Record 44 of Set 5 | periyapatti
# Processing Record 45 of Set 5 | swan hill
# Processing Record 46 of Set 5 | kolonia
# Processing Record 47 of Set 5 | ambodifotatra
# Processing Record 48 of Set 5 | tadine
# Processing Record 49 of Set 5 | mosjoen
# Processing Record 0 of Set 6 | olonkinbyen
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | selfoss
# Processing Record 3 of Set 6 | elliot lake
# Processing Record 4 of Set 6 | nar'yan-mar
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | abagur
# Processing Record 8 of Set 6 | grand gaube
# Processing Record 9 of Set 6 | qalat
# Processing Record 10 of Set 6 | akureyri
# Processing Record 11 of Set 6 | arraial do cabo
# Processing Record 12 of Set 6 | new plymouth
# Processing Record 13 of Set 6 | yuanping
# Processing Record 14 of Set 6 | vorgashor
# Processing Record 15 of Set 6 | hoi an
# Processing Record 16 of Set 6 | pimentel
# Processing Record 17 of Set 6 | bengkulu
# Processing Record 18 of Set 6 | birobidzhan
# Processing Record 19 of Set 6 | belmonte
# Processing Record 20 of Set 6 | erenhot
# Processing Record 21 of Set 6 | calatayud
# Processing Record 22 of Set 6 | cascais
# Processing Record 23 of Set 6 | northam
# Processing Record 24 of Set 6 | vilyuchinsk
# Processing Record 25 of Set 6 | wenceslau braz
# Processing Record 26 of Set 6 | kani keli
# Processing Record 27 of Set 6 | as sulayyil
# Processing Record 28 of Set 6 | tromso
# Processing Record 29 of Set 6 | carei
# Processing Record 30 of Set 6 | ainaro
# Processing Record 31 of Set 6 | imola
# Processing Record 32 of Set 6 | acarau
# Processing Record 33 of Set 6 | port mathurin
# Processing Record 34 of Set 6 | arkhangel'sk
# Processing Record 35 of Set 6 | vadso
# Processing Record 36 of Set 6 | afonso claudio
# Processing Record 37 of Set 6 | dubai
# Processing Record 38 of Set 6 | bayanhongor
# Processing Record 39 of Set 6 | amga
# Processing Record 40 of Set 6 | crane
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | sydney
# Processing Record 43 of Set 6 | porto de moz
# Processing Record 44 of Set 6 | mulino
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | puerto baquerizo moreno
# Processing Record 47 of Set 6 | outapi
# City not found. Skipping...
# Processing Record 48 of Set 6 | brookings
# Processing Record 49 of Set 6 | bandon
# Processing Record 0 of Set 7 | quelimane
# Processing Record 1 of Set 7 | nemuro
# Processing Record 2 of Set 7 | acapulco de juarez
# Processing Record 3 of Set 7 | bobrov
# Processing Record 4 of Set 7 | bechar
# Processing Record 5 of Set 7 | mossel bay
# Processing Record 6 of Set 7 | nevada
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | rongelap
# Processing Record 10 of Set 7 | anadyr
# Processing Record 11 of Set 7 | farasan
# Processing Record 12 of Set 7 | wuwei
# Processing Record 13 of Set 7 | brezina
# Processing Record 14 of Set 7 | powell river
# Processing Record 15 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 16 of Set 7 | dili
# Processing Record 17 of Set 7 | antsiranana
# Processing Record 18 of Set 7 | isla del bosque
# Processing Record 19 of Set 7 | olinda
# Processing Record 20 of Set 7 | anuradhapura
# Processing Record 21 of Set 7 | tyukalinsk
# Processing Record 22 of Set 7 | queenstown
# Processing Record 23 of Set 7 | dzhangala
# Processing Record 24 of Set 7 | avarua
# Processing Record 25 of Set 7 | vallenar
# Processing Record 26 of Set 7 | badger
# Processing Record 27 of Set 7 | chongwe
# Processing Record 28 of Set 7 | talcahuano
# Processing Record 29 of Set 7 | shimoda
# Processing Record 30 of Set 7 | phongsali
# Processing Record 31 of Set 7 | westport
# Processing Record 32 of Set 7 | hastings
# Processing Record 33 of Set 7 | keflavik
# Processing Record 34 of Set 7 | geneina
# Processing Record 35 of Set 7 | illizi
# Processing Record 36 of Set 7 | parnu
# Processing Record 37 of Set 7 | hilo
# Processing Record 38 of Set 7 | mokhsogollokh
# Processing Record 39 of Set 7 | verkhnevilyuysk
# Processing Record 40 of Set 7 | chake chake
# Processing Record 41 of Set 7 | forquilha
# Processing Record 42 of Set 7 | patigi
# Processing Record 43 of Set 7 | veinticinco de mayo
# Processing Record 44 of Set 7 | hauterive
# Processing Record 45 of Set 7 | constantia
# Processing Record 46 of Set 7 | udachny
# Processing Record 47 of Set 7 | quellon
# Processing Record 48 of Set 7 | gadzhiyevo
# Processing Record 49 of Set 7 | sur
# Processing Record 0 of Set 8 | alice springs
# Processing Record 1 of Set 8 | shiguai
# Processing Record 2 of Set 8 | sinop
# Processing Record 3 of Set 8 | khanty-mansiysk
# Processing Record 4 of Set 8 | narvik
# Processing Record 5 of Set 8 | boca suno
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | minas de marcona
# Processing Record 8 of Set 8 | jijel
# Processing Record 9 of Set 8 | ulladulla
# Processing Record 10 of Set 8 | lethem
# Processing Record 11 of Set 8 | filadelfia
# Processing Record 12 of Set 8 | antofagasta
# Processing Record 13 of Set 8 | johi
# Processing Record 14 of Set 8 | nouadhibou
# Processing Record 15 of Set 8 | enewetak
# Processing Record 16 of Set 8 | itacarambi
# Processing Record 17 of Set 8 | angaur state
# Processing Record 18 of Set 8 | nosy varika
# Processing Record 19 of Set 8 | katsuura
# Processing Record 20 of Set 8 | santa ines
# Processing Record 21 of Set 8 | carmo do rio verde
# Processing Record 22 of Set 8 | zaozersk
# Processing Record 23 of Set 8 | itaituba
# Processing Record 24 of Set 8 | perugorria
# Processing Record 25 of Set 8 | usogorsk
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 8 | sherbakul'
# Processing Record 30 of Set 8 | dakhla
# Processing Record 31 of Set 8 | sergiyev posad
# Processing Record 32 of Set 8 | derzhavinsk
# Processing Record 33 of Set 8 | dalandzadgad
# Processing Record 34 of Set 8 | flying fish cove
# Processing Record 35 of Set 8 | pariaman
# Processing Record 36 of Set 8 | la rinconada
# Processing Record 37 of Set 8 | christchurch
# Processing Record 38 of Set 8 | onega
# Processing Record 39 of Set 8 | san pedro pochutla
# Processing Record 40 of Set 8 | ivdel'
# Processing Record 41 of Set 8 | novo oriente
# Processing Record 42 of Set 8 | sao joao da barra
# Processing Record 43 of Set 8 | kars
# Processing Record 44 of Set 8 | kiunga
# Processing Record 45 of Set 8 | thief river falls
# Processing Record 46 of Set 8 | lompoc
# Processing Record 47 of Set 8 | lautoka
# Processing Record 48 of Set 8 | shalqar
# Processing Record 49 of Set 8 | kuanda
# Processing Record 0 of Set 9 | severo-yeniseyskiy
# Processing Record 1 of Set 9 | kotido
# Processing Record 2 of Set 9 | machina
# Processing Record 3 of Set 9 | santa flavia
# Processing Record 4 of Set 9 | xining
# Processing Record 5 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 9 | lubang
# Processing Record 7 of Set 9 | upper grand lagoon
# Processing Record 8 of Set 9 | carbonear
# Processing Record 9 of Set 9 | tual
# Processing Record 10 of Set 9 | kayyerkan
# Processing Record 11 of Set 9 | banjar
# Processing Record 12 of Set 9 | chust
# Processing Record 13 of Set 9 | mount isa
# Processing Record 14 of Set 9 | nagqu
# Processing Record 15 of Set 9 | andijon
# Processing Record 16 of Set 9 | dom pedrito
# Processing Record 17 of Set 9 | alofi
# Processing Record 18 of Set 9 | remire-montjoly
# Processing Record 19 of Set 9 | starokucherganovka
# Processing Record 20 of Set 9 | smithers
# Processing Record 21 of Set 9 | princeville
# Processing Record 22 of Set 9 | kostanay
# Processing Record 23 of Set 9 | nema
# Processing Record 24 of Set 9 | sao raimundo nonato
# Processing Record 25 of Set 9 | merowe
# Processing Record 26 of Set 9 | yuzhno-kurilsk
# Processing Record 27 of Set 9 | rawai
# Processing Record 28 of Set 9 | petrov val
# Processing Record 29 of Set 9 | lincoln
# Processing Record 30 of Set 9 | sawankhalok
# Processing Record 31 of Set 9 | ta`u
# Processing Record 32 of Set 9 | usinsk
# Processing Record 33 of Set 9 | margate
# Processing Record 34 of Set 9 | oranjestad
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | radomsko
# Processing Record 37 of Set 9 | sitka
# Processing Record 38 of Set 9 | rouissat
# Processing Record 39 of Set 9 | yaren
# Processing Record 40 of Set 9 | mashhad
# Processing Record 41 of Set 9 | chebba
# Processing Record 42 of Set 9 | fort mcmurray
# Processing Record 43 of Set 9 | binghamton
# Processing Record 44 of Set 9 | el bauga
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 47 of Set 9 | ipueiras
# Processing Record 48 of Set 9 | callao
# Processing Record 49 of Set 9 | diamantino
# Processing Record 0 of Set 10 | santa cruz
# Processing Record 1 of Set 10 | santa eularia des riu
# Processing Record 2 of Set 10 | leticia
# Processing Record 3 of Set 10 | ad dabbah
# Processing Record 4 of Set 10 | entebbe
# Processing Record 5 of Set 10 | marshalltown
# Processing Record 6 of Set 10 | barra de santo antonio
# Processing Record 7 of Set 10 | leh
# Processing Record 8 of Set 10 | nelson bay
# Processing Record 9 of Set 10 | carutapera
# Processing Record 10 of Set 10 | sunne
# Processing Record 11 of Set 10 | ust-tsilma
# Processing Record 12 of Set 10 | fada
# Processing Record 13 of Set 10 | sisophon
# Processing Record 14 of Set 10 | buala
# Processing Record 15 of Set 10 | tarabha
# Processing Record 16 of Set 10 | aitape
# Processing Record 17 of Set 10 | chandler
# Processing Record 18 of Set 10 | lastoursville
# Processing Record 19 of Set 10 | hammerfest
# Processing Record 20 of Set 10 | paita
# Processing Record 21 of Set 10 | the pas
# Processing Record 22 of Set 10 | trenggalek
# Processing Record 23 of Set 10 | fuyuan
# Processing Record 24 of Set 10 | tangalle
# Processing Record 25 of Set 10 | tofol
# Processing Record 26 of Set 10 | port-cartier
# Processing Record 27 of Set 10 | wayne
# Processing Record 28 of Set 10 | puerto colombia
# Processing Record 29 of Set 10 | sal rei
# Processing Record 30 of Set 10 | sirte
# Processing Record 31 of Set 10 | springfield
# Processing Record 32 of Set 10 | mandera
# Processing Record 33 of Set 10 | tacna
# Processing Record 34 of Set 10 | new hamburg
# Processing Record 35 of Set 10 | mozarlandia
# Processing Record 36 of Set 10 | madzhalis
# Processing Record 37 of Set 10 | kuvshinovo
# Processing Record 38 of Set 10 | nizhneangarsk
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | calbuco
# Processing Record 41 of Set 10 | chui
# Processing Record 42 of Set 10 | greenwood
# Processing Record 43 of Set 10 | ahar
# Processing Record 44 of Set 10 | thal
# Processing Record 45 of Set 10 | kattivakkam
# Processing Record 46 of Set 10 | dikili
# Processing Record 47 of Set 10 | tanumah
# Processing Record 48 of Set 10 | kavaratti
# Processing Record 49 of Set 10 | chuhar jamali
# Processing Record 0 of Set 11 | san fernando de apure
# Processing Record 1 of Set 11 | nadym
# Processing Record 2 of Set 11 | karor
# Processing Record 3 of Set 11 | barakani
# Processing Record 4 of Set 11 | rosoman
# Processing Record 5 of Set 11 | conde
# Processing Record 6 of Set 11 | kongoussi
# Processing Record 7 of Set 11 | kerikeri
# Processing Record 8 of Set 11 | ca mau
# Processing Record 9 of Set 11 | cidade velha
# Processing Record 10 of Set 11 | huilong
# Processing Record 11 of Set 11 | uryupinsk
# Processing Record 12 of Set 11 | taro
# Processing Record 13 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 14 of Set 11 | big spring
# Processing Record 15 of Set 11 | chivhu
# Processing Record 16 of Set 11 | tucuma
# Processing Record 17 of Set 11 | slantsy
# Processing Record 18 of Set 11 | bikenibeu village
# Processing Record 19 of Set 11 | san antonio de pale
# Processing Record 20 of Set 11 | yanbu
# Processing Record 21 of Set 11 | sakaiminato
# Processing Record 22 of Set 11 | yung shue wan
# Processing Record 23 of Set 11 | ghadamis
# Processing Record 24 of Set 11 | dompu
# Processing Record 25 of Set 11 | mont-laurier
# Processing Record 26 of Set 11 | yeraliyev
# Processing Record 27 of Set 11 | i-n-salah
# Processing Record 28 of Set 11 | senador jose porfirio
# Processing Record 29 of Set 11 | sola
# Processing Record 30 of Set 11 | uvinza
# Processing Record 31 of Set 11 | batesville
# Processing Record 32 of Set 11 | manismata
# Processing Record 33 of Set 11 | nieuw amsterdam
# Processing Record 34 of Set 11 | xilin hot
# Processing Record 35 of Set 11 | howrah
# Processing Record 36 of Set 11 | macapa
# Processing Record 37 of Set 11 | kol'chugino
# Processing Record 38 of Set 11 | savanna-la-mar
# Processing Record 39 of Set 11 | lushun
# Processing Record 40 of Set 11 | mukalla
# Processing Record 41 of Set 11 | danville
# Processing Record 42 of Set 11 | jiaxing
# Processing Record 43 of Set 11 | robertsport
# Processing Record 44 of Set 11 | san andres
# Processing Record 45 of Set 11 | ambo
# Processing Record 46 of Set 11 | anna regina
# Processing Record 47 of Set 11 | igarka
# Processing Record 48 of Set 11 | mahibadhoo
# Processing Record 49 of Set 11 | machali
# Processing Record 0 of Set 12 | iiyama
# Processing Record 1 of Set 12 | cayambe
# Processing Record 2 of Set 12 | aberdeen
# Processing Record 3 of Set 12 | huanggang
# Processing Record 4 of Set 12 | fort st. john
# Processing Record 5 of Set 12 | oliver
# Processing Record 6 of Set 12 | fremont
# Processing Record 7 of Set 12 | kenai
# Processing Record 8 of Set 12 | preobrazheniye
# Processing Record 9 of Set 12 | ghormach
# Processing Record 10 of Set 12 | amasra
# Processing Record 11 of Set 12 | korla
# Processing Record 12 of Set 12 | koneurgench
# City not found. Skipping...
# Processing Record 13 of Set 12 | colonia
# Processing Record 14 of Set 12 | eagle pass
# Processing Record 15 of Set 12 | abinsk
# Processing Record 16 of Set 12 | kodiak
# Processing Record 17 of Set 12 | estevan
# Processing Record 18 of Set 12 | pyrgos
# Processing Record 19 of Set 12 | whyalla stuart
# City not found. Skipping...
# Processing Record 20 of Set 12 | gandajika
# Processing Record 21 of Set 12 | slyudyanka
# Processing Record 22 of Set 12 | minas novas
# Processing Record 23 of Set 12 | blagoveshchensk
# Processing Record 24 of Set 12 | khorinsk
# Processing Record 25 of Set 12 | bozoum
# Processing Record 26 of Set 12 | la'ie
# Processing Record 27 of Set 12 | boende
# Processing Record 28 of Set 12 | carira
# Processing Record 29 of Set 12 | lorengau
# Processing Record 30 of Set 12 | novyy urgal
# Processing Record 31 of Set 12 | miles city
# Processing Record 32 of Set 12 | san isidro de curuguaty
# Processing Record 33 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 12 | fauske
# Processing Record 35 of Set 12 | kuala terengganu
# Processing Record 36 of Set 12 | uribia
# Processing Record 37 of Set 12 | inarajan village
# Processing Record 38 of Set 12 | haiku-pauwela
# Processing Record 39 of Set 12 | juneau
# Processing Record 40 of Set 12 | kristianstad
# Processing Record 41 of Set 12 | porto novo
# Processing Record 42 of Set 12 | aimores
# Processing Record 43 of Set 12 | corfu
# Processing Record 44 of Set 12 | gaiman
# Processing Record 45 of Set 12 | aioun
# Processing Record 46 of Set 12 | yakeshi
# Processing Record 47 of Set 12 | arroyo
# Processing Record 48 of Set 12 | beira
# Processing Record 49 of Set 12 | zouerate
# Processing Record 0 of Set 13 | novoul'yanovsk
# Processing Record 1 of Set 13 | solnechnyy
# Processing Record 2 of Set 13 | nkurenkuru
# City not found. Skipping...
# Processing Record 3 of Set 13 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 4 of Set 13 | nova vicosa
# Processing Record 5 of Set 13 | mae ramat
# Processing Record 6 of Set 13 | kalymnos
# Processing Record 7 of Set 13 | ambad
# Processing Record 8 of Set 13 | kodinsk
# Processing Record 9 of Set 13 | severnoye
# Processing Record 10 of Set 13 | lionel town
# Processing Record 11 of Set 13 | bel ombre
# Processing Record 12 of Set 13 | sanford
# Processing Record 13 of Set 13 | aden
# Processing Record 14 of Set 13 | zuunmod
# Processing Record 15 of Set 13 | paracuru
# Processing Record 16 of Set 13 | luwuk
# Processing Record 17 of Set 13 | dazhou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          598
# Lat           598
# Lng           598
# Max Temp      598
# Humidity      598
# Cloudiness    598
# Wind Speed    598
# Country       598
# Date          598
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      waitangi -43.9535 -176.5597      8.23        90         100
# 1      sampacho -33.3839  -64.7221     10.04        46          29
# 2     salekhard  66.5300   66.6019     19.61        77           5
# 3   peace river  56.2501 -117.2860     21.17        40          40
# 4  meadow lakes  61.6247 -149.6011     21.17        66           0
#
#    Wind Speed Country        Date
# 0        3.58      NZ  1690512615
# 1        3.33      AR  1690512556
# 2        3.08      RU  1690512615
# 3        3.60      CA  1690512480
# 4        2.57      US  1690512615

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            waitangi -43.9535 -176.5597      8.23        90         100
# 1            sampacho -33.3839  -64.7221     10.04        46          29
# 2           salekhard  66.5300   66.6019     19.61        77           5
# 3         peace river  56.2501 -117.2860     21.17        40          40
# 4        meadow lakes  61.6247 -149.6011     21.17        66           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.58      NZ  1690512615
# 1              3.33      AR  1690512556
# 2              3.08      RU  1690512615
# 3              3.60      CA  1690512480
# 4              2.57      US  1690512615

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

lat=city_data_df['Lat']
temp=city_data_df['Max Temp']
t=datetime.date.today()


plt.scatter(lat, temp, marker='o', facecolors='red', edgecolors='yellow',alpha=1)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Max Temperature({t})\n')
plt.ylabel('Max Temperature (C)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat=city_data_df['Lat']
hum=city_data_df['Humidity']
t= datetime.date.today()
plt.scatter(lat, hum, marker='v', facecolors='blue', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs Humidity ({t}) \n')
plt.ylabel('Humidity(%)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs.Cloudiness
lat=city_data_df['Lat']
cl=city_data_df['Cloudiness']
t= datetime.date.today()
plt.scatter(lat, cl, marker='s', facecolors='gray', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Cloudiness({t})\n')
plt.ylabel('Cloudiness(%)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. Wind Speed
# Build the scatter plots for latitude vs.Cloudiness
lat=city_data_df['Lat']
wind=city_data_df['Cloudiness']
t= datetime.date.today()
plt.scatter(lat, wind, marker='d', facecolors='green', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Wind Speed({t})\n')
plt.ylabel('Wind Speed(m/s)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_value(x_values, y_values,title,coordinats):
    r = scipy.stats.pearsonr(x_values, y_values)
    print(f"The r-value is: {r[0]}")
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    regress_values= x_values*slope+intercept
    
    line_eq='y='+str(round(slope,2))+'x+'+ str(round(intercept,2))
    plt.plot(x_values,regress_values,'green')
    plt.annotate(line_eq, coordinats,fontsize=15,color='red')
    
    plt.scatter(x_values, y_values, marker='o', facecolors='blue', edgecolors='gray',alpha=0.75)
    
    plt.ylabel(title)
    
    plt.xlabel('Latitude')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>0]
# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           salekhard  66.5300   66.6019     19.61        77           5
# 3         peace river  56.2501 -117.2860     21.17        40          40
# 4        meadow lakes  61.6247 -149.6011     21.17        66           0
# 7               tiksi  71.6872  128.8694      9.93        61          56
# 9         nova sintra  14.8667  -24.7167     22.48        81          19
#
#          Wind Speed Country        Date
# City_ID
# 2              3.08      RU  1690512615
# 3              3.60      CA  1690512480
# 4              2.57      US  1690512615
# 7              4.02      RU  1690512616
# 9              7.95      CV  1690512616

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              waitangi -43.9535 -176.5597      8.23        90         100
# 1              sampacho -33.3839  -64.7221     10.04        46          29
# 5            codrington -38.2667  141.9667     15.79        67           4
# 6              afaahiti -17.7500 -149.2833     24.93        86          33
# 8        port elizabeth -33.9180   25.5701     11.16        93           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.58      NZ  1690512615
# 1              3.33      AR  1690512556
# 5              5.76      AU  1690512616
# 6              4.24      PF  1690512616
# 8              1.54      ZA  1690512616

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Temperature vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere
lat=northern_hemi_df['Lat']
temp=northern_hemi_df['Max Temp']
# Call the function
regress_value(lat,temp,'Max Temperaure',(5,10))
# Out:
# The r-value is: -0.5815593107565276

# %% [markdown]
# ##### Temperature vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on Southern Hemisphere

lat=southern_hemi_df['Lat']
temp=southern_hemi_df['Max Temp']
# Call the function
regress_value(lat,temp,'Max Temperaure',(-30,5))
# Out:
# The r-value is: 0.8228836978953136

# %% [markdown]
# **Discussion about the linear relationship:
# - There is a negative correlation between temperature and latitude with a negative correlation coefficient in the Northern Hemisphere.
# - The r-value is between -0.7 and -0.5. The Temperature and Latitude are considered moderately correlated in the Northern Hemisphere.
#
# - There is a positive correlation between temperature and latitude with a positive correlation coefficient in the Southern Hemisphere.
#
# - The r-value is higher than 0.7. The Temperature and Latitude are considered highly correlated in the Northern Hemisphere.
#
# ##### Example of Max temperatures in cities in the Southern Hemisphere on 7/27/23 :
#
# Map that displays a point for some cities on Southern Hemisphere. The size of the points represents the Max temperature in each city.
#
# <img src='output_data/lat.temp.png' style ='width:700px;height:300px'/>
# When we get closer to the equator (latitude = 0), the size of the points becomes bigger.
#
# -->Temperature is inversely related to latitude. As latitude increases, the temperature falls, and vice versa. Generally, around the world, it gets warmer towards the equator and cooler towards the poles

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Humidity vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
hum=northern_hemi_df['Humidity']
# Call the function
regress_value(lat,hum,'Humidity(%)',(50,20))
# Out:
# The r-value is: -0.012989286084868391

# %% [markdown]
# ##### Humidity vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on southern Hemisphere

lat=southern_hemi_df['Lat']
hum=southern_hemi_df['Humidity']
# Call the function
regress_value(lat,hum,'Humidity(%)',(-48,30))
# Out:
# The r-value is: -0.039401669564788855

# %% [markdown]
# **Discussion about the linear relationship:
#
# - The correlation between Humidity and Latitude is close to 0 in the Northern Hemisphere and Southern Hemisphere.
#
# - The r-value is not significant. There is no correlation between Humidity and Latitude in the Northern Hemisphere and Southern Hemisphere.
#
# - r- value is not significant; a regression analysis should never be done.
#
# ##### Example of Humidity in cities in the Southern Hemisphere on 7/27/23:
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Humidity in each city.
#
# <img src='output_data/lat.hum.png' style ='width:700px;height:300px'/>
# The size of the points isn't dependent on the location as it relates to the equator.
#
# --> Relative humidity is maximum near the equator, but decreases in subtropical areas and increases again in temperate regions.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Cloudiness vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
cl=northern_hemi_df['Cloudiness']
# Call the function
regress_value(lat,cl,'Cloudiness(%)',(2,2))
# Out:
# The r-value is: -0.02366378232616085

# %% [markdown]
# ##### Cloudiness vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=southern_hemi_df['Lat']
cl=southern_hemi_df['Cloudiness']
# Call the function
regress_value(lat,cl,'Cloudiness(%)',(-50,25))
# Out:
# The r-value is: -0.03270638191216796

# %% [markdown]
# **Discussion about the linear relationship
#
# - The correlation between Humidity and Latitude is close to 0 in the Northern Hemisphere and Southern Hemisphere.
#
# - The r-value is not significant. There is no correlation between Humidity and Latitude in the Northern Hemisphere and Southern Hemisphere.
#
# - r- value is not significant; a regression analysis should never be done.
#
# ##### Example of Cloudiness in cities in the Southern Hemisphere on 7/27/23 :
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Cloudiness in each city.
#
# <img src='output_data/lat.cl.png' style ='width:700px;height:300px'/>
# The size of the points isn't dependent on the location as it relates to the equator.
#
# --> Cloudiness is not related to latitude. There is a high degree of variance in cloudiness across all latitudes, suggesting that latitude does not cause an area to be more or less cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Wind Speed vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
wind=northern_hemi_df['Wind Speed']
# Call the function
regress_value(lat,wind,'Wind Speed(m/s)',(10,14))
# Out:
# The r-value is: -0.30499371031760747

# %% [markdown]
# ##### Wind Speed vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
#Linear regression on Sourthern Hemisphere

lat=southern_hemi_df['Lat']
wind=southern_hemi_df['Wind Speed']
# Call the function
regress_value(lat,wind,'Wind Speed(m/s)',(-50,15))
# Out:
# The r-value is: 0.019747008592260123

# %% [markdown]
# **Discussion about the linear relationship:
#
# The correlation between Wind Speed and Latitude is very weak on Northern Hemisphere and Southern Hemisphere.
# The r-value is between -0.2 and 0. There is a very weak negative correlation between Wind Speed and Latitude on Northern Hemisphere and Southern Hemisphere.
#
# ##### Example of Wind Speed in cities in the Southern Hemisphere on 7/27/23:
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Wind speed in each city.
#
# <img src='output_data/lat.wind.png' style ='width:700px;height:300px'/>
# The size of the points is not dependent on the location as it relates to the equator
#
# --> The latitude can impact the direction of the wind, not the speed.
